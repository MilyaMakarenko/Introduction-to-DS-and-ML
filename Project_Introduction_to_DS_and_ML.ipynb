# %% [markdown]
# ### Проект курса Введение в DS и ML
#
# от Анатоля Карпова
#
# ___
#
# Практическим проектом нашего курса будет анализ активности студентов онлайн курса **Введение в анализ данных в R**.

# %%
import numpy as np
import pandas as pd

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(rc={'figure.figsize': (10, 6)})

# %% [markdown]
# Описание данных:
#
# events_train.csv - данные о действиях, которые совершают студенты со стэпами
#
#     step_id - id стэпа
#     user_id - анонимизированный id юзера
#     timestamp - время наступления события в формате unix date
#     action - событие, возможные значения:
#
#     discovered - пользователь перешел на стэп
#     viewed - просмотр шага,
#     started_attempt - начало попытки решить шаг, ранее нужно было явно нажать на кнопку - начать решение, перед тем как приступить к решению практического шага
#     passed - удачное решение практического шага
#
# submissions_train.csv - данные о времени и статусах сабмитов к практическим заданиям
#
#     step_id - id стэпа
#     timestamp - время отправки решения в формате unix date
#     submission_status - статус решения
#     user_id - анонимизированный id юзера

# %%
events_data = pd.read_csv(r'C:\Users\admin\jupyter_notebook\event_data_train.csv')
events_data
# Out:
#          step_id   timestamp      action  user_id
# 0          32815  1434340848      viewed    17632
# 1          32815  1434340848      passed    17632
# 2          32815  1434340848  discovered    17632
# 3          32811  1434340895  discovered    17632
# 4          32811  1434340895      viewed    17632
# ...          ...         ...         ...      ...
# 3480698    33375  1526772685      viewed    11677
# 3480699    32815  1526772750      viewed     5198
# 3480700    32815  1526772750  discovered     5198
# 3480701    32815  1526772750      passed     5198
# 3480702    33892  1526772811      viewed    18526
#
# [3480703 rows x 4 columns]

# %%
submissions_data = pd.read_csv(r'C:\Users\admin\jupyter_notebook\submissions_data_train.csv')
submissions_data
# Out:
#         step_id   timestamp submission_status  user_id
# 0         31971  1434349275           correct    15853
# 1         31972  1434348300           correct    15853
# 2         31972  1478852149             wrong    15853
# 3         31972  1478852164           correct    15853
# 4         31976  1434348123             wrong    15853
# ...         ...         ...               ...      ...
# 509099   120745  1501946959             wrong     2615
# 509100   120745  1503059927           correct    13177
# 509101   120745  1506348153             wrong    15253
# 509102   120745  1523035316             wrong     1424
# 509103   120745  1523382825             wrong     9422
#
# [509104 rows x 4 columns]

# %% [markdown]
# Поисследуем данные

# %%
events_data.action.unique() #виды действий пользователей
# Out:
# array(['viewed', 'passed', 'discovered', 'started_attempt'], dtype=object)

# %%
events_data.step_id.nunique() #количество степов
# Out:
# 198

# %%
events_data.user_id.nunique() #количество уникальных пользователей
# Out:
# 19234

# %%
def EpochTimeToStr(timestamp, *, round_ = 6):
    import time
    s = time.strftime('%Y.%m.%d %H:%M:%S', time.gmtime(timestamp))
    s += ('%.9f' % round(timestamp - int(timestamp), round_))[1:].rstrip('0').rstrip('.')
    s += ' UTC'
    return s

# %% [markdown]
# Посмотрим дату первого события

# %%
t = events_data.timestamp[0]
EpochTimeToStr(t)
# Out:
# '2015.06.15 04:00:48 UTC'

# %% [markdown]
# Посмотрим дату последнего события

# %%
t = events_data.timestamp[3480702]
EpochTimeToStr(t)
# Out:
# '2018.05.19 23:33:31 UTC'

# %% [markdown]
# Дополним столбцом с датой в привычном виде

# %%
events_data['date'] = pd.to_datetime(events_data.timestamp, unit='s')

# %%
submissions_data['date'] = pd.to_datetime(submissions_data.timestamp, unit='s')

# %%
events_data
# Out:
#          step_id   timestamp      action  user_id                date
# 0          32815  1434340848      viewed    17632 2015-06-15 04:00:48
# 1          32815  1434340848      passed    17632 2015-06-15 04:00:48
# 2          32815  1434340848  discovered    17632 2015-06-15 04:00:48
# 3          32811  1434340895  discovered    17632 2015-06-15 04:01:35
# 4          32811  1434340895      viewed    17632 2015-06-15 04:01:35
# ...          ...         ...         ...      ...                 ...
# 3480698    33375  1526772685      viewed    11677 2018-05-19 23:31:25
# 3480699    32815  1526772750      viewed     5198 2018-05-19 23:32:30
# 3480700    32815  1526772750  discovered     5198 2018-05-19 23:32:30
# 3480701    32815  1526772750      passed     5198 2018-05-19 23:32:30
# 3480702    33892  1526772811      viewed    18526 2018-05-19 23:33:31
#
# [3480703 rows x 5 columns]

# %%
events_data['day'] = events_data.date.dt.date
events_data
# Out:
#          step_id   timestamp      action  user_id                date  \
# 0          32815  1434340848      viewed    17632 2015-06-15 04:00:48
# 1          32815  1434340848      passed    17632 2015-06-15 04:00:48
# 2          32815  1434340848  discovered    17632 2015-06-15 04:00:48
# 3          32811  1434340895  discovered    17632 2015-06-15 04:01:35
# 4          32811  1434340895      viewed    17632 2015-06-15 04:01:35
# ...          ...         ...         ...      ...                 ...
# 3480698    33375  1526772685      viewed    11677 2018-05-19 23:31:25
# 3480699    32815  1526772750      viewed     5198 2018-05-19 23:32:30
# 3480700    32815  1526772750  discovered     5198 2018-05-19 23:32:30
# 3480701    32815  1526772750      passed     5198 2018-05-19 23:32:30
# 3480702    33892  1526772811      viewed    18526 2018-05-19 23:33:31
#
#                 day
# 0        2015-06-15
# 1        2015-06-15
# 2        2015-06-15
# 3        2015-06-15
# ...

# %%
submissions_data['day'] = submissions_data.date.dt.date

# %%
events_data.groupby('day', as_index=False) \
    .user_id.nunique()
# Out:
#              day  user_id
# 0     2015-06-15      705
# 1     2015-06-16      526
# 2     2015-06-17      440
# 3     2015-06-18      411
# 4     2015-06-19      377
# ...          ...      ...
# 1065  2018-05-15      145
# 1066  2018-05-16      155
# 1067  2018-05-17      165
# 1068  2018-05-18      126
# 1069  2018-05-19      131
#
# [1070 rows x 2 columns]

# %%
events_data.groupby('day') \
    .user_id.nunique().plot()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
events_data.query('action == "passed"') \
    .groupby('user_id', as_index=False) \
    .agg({'step_id': 'count'}) \
    .rename(columns={'step_id': 'passed_step'})
# Out:
#        user_id  passed_step
# 0            2            9
# 1            3           87
# 2            5           11
# 3            7            1
# 4            8           84
# ...        ...          ...
# 17257    26789            2
# 17258    26790            8
# 17259    26794           69
# 17260    26797           10
# 17261    26798           12
#
# [17262 rows x 2 columns]

# %%
events_data.query('action == "passed"') \
    .groupby('user_id', as_index=False) \
    .agg({'step_id': 'count'}) \
    .rename(columns={'step_id': 'passed_step'}).passed_step.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Мы потеряли людей, которые не закончили степ

# %% [markdown]
# Давайте для тех, кто не прошел ни один степ, проставим 0

# %%
users_events_data = events_data.pivot_table(index='user_id', 
                        columns='action', 
                        values='step_id', 
                        aggfunc='count', 
                        fill_value=0).reset_index()

# %%
users_events_data
# Out:
# action  user_id  discovered  passed  started_attempt  viewed
# 0             1           1       0                0       1
# 1             2           9       9                2      10
# 2             3          91      87               30     192
# 3             5          11      11                4      12
# 4             7           1       1                0       1
# ...         ...         ...     ...              ...     ...
# 19229     26790           8       8                1       9
# 19230     26793           1       0                1       1
# 19231     26794          69      69               34     180
# 19232     26797          10      10                2      13
# 19233     26798          12      12                3      12
#
# [19234 rows x 5 columns]

# %%
events_data.pivot_table(index='user_id', 
                        columns='action', 
                        values='step_id', 
                        aggfunc='count', 
                        fill_value=0).reset_index().discovered.hist()
# Out:
# <AxesSubplot:>

# %%
submissions_data
# Out:
#         step_id   timestamp submission_status  user_id                date  \
# 0         31971  1434349275           correct    15853 2015-06-15 06:21:15
# 1         31972  1434348300           correct    15853 2015-06-15 06:05:00
# 2         31972  1478852149             wrong    15853 2016-11-11 08:15:49
# 3         31972  1478852164           correct    15853 2016-11-11 08:16:04
# 4         31976  1434348123             wrong    15853 2015-06-15 06:02:03
# ...         ...         ...               ...      ...                 ...
# 509099   120745  1501946959             wrong     2615 2017-08-05 15:29:19
# 509100   120745  1503059927           correct    13177 2017-08-18 12:38:47
# 509101   120745  1506348153             wrong    15253 2017-09-25 14:02:33
# 509102   120745  1523035316             wrong     1424 2018-04-06 17:21:56
# 509103   120745  1523382825             wrong     9422 2018-04-10 17:53:45
#
#                day
# 0       2015-06-15
# 1       2015-06-15
# ...

# %%
users_scores = submissions_data.pivot_table(index='user_id', 
                        columns='submission_status', 
                        values='step_id', 
                        aggfunc='count', 
                        fill_value=0).reset_index()

# %%
users_scores
# Out:
# submission_status  user_id  correct  wrong
# 0                        2        2      0
# 1                        3       29     23
# 2                        5        2      2
# 3                        8        9     21
# 4                       14        0      1
# ...                    ...      ...    ...
# 9935                 26787        3      0
# 9936                 26790        1      0
# 9937                 26794       33      9
# 9938                 26797        2      0
# 9939                 26798        2      1
#
# [9940 rows x 3 columns]

# %% [markdown]
# Хотим предсказать тех пользоваелей, которые удалились из курса, не дорешали его до конца и ушли, и больше не вернулись

# %% [markdown]
# Оставим только нужные нам столбцы

# %%
events_data[['user_id', 'day', 'timestamp']].drop_duplicates(subset=['user_id', 'day']) \
    .groupby('user_id')['timestamp'].apply(list)
# Out:
# user_id
# 1                                             [1472827464]
# 2                                 [1514383364, 1519226966]
# 3        [1434358476, 1441257725, 1441440209, 144153391...
# 5                                 [1466156809, 1499859621]
# 7                                             [1521634660]
#                                ...
# 26790     [1451484016, 1451722241, 1452616205, 1517495853]
# 26793                                         [1510225031]
# 26794    [1495287049, 1495373177, 1495509936, 149560483...
# 26797                             [1508425316, 1509993306]
# 26798                                         [1520975763]
# Name: timestamp, Length: 19234, dtype: object

# %% [markdown]
# Какие были перерывы между этими днями

# %%
gap_data = events_data[['user_id', 'day', 'timestamp']].drop_duplicates(subset=['user_id', 'day']) \
    .groupby('user_id')['timestamp'].apply(list) \
    .apply(np.diff).values

# %%
gap_data = pd.Series(np.concatenate(gap_data, axis=0))

# %%
gap_data = gap_data / (24 * 60 * 60)

# %%
gap_data[gap_data > 200].hist()
# Out:
# <AxesSubplot:>

# %%
gap_data.quantile(0.95)
# Out:
# 59.760440972222156

# %%
events_data.query('action == "viewed"').groupby('user_id').agg({'action': 'count'}).sort_values('action', ascending=False)
# Out:
#          action
# user_id
# 20907     32778
# 10794     16089
# 25279      9693
# 1046       8122
# 3572       6968
# ...         ...
# 7549          1
# 7551          1
# 7554          1
# 7556          1
# 1             1
#
# [19227 rows x 1 columns]

# %%
submissions_data.query('submission_status == "correct"').groupby('user_id').agg({'submission_status': 'count'}).sort_values('submission_status', ascending=False)
# Out:
#          submission_status
# user_id
# 1046                   421
# 5552                   186
# 17135                  168
# 6183                   142
# 8461                   135
# ...                    ...
# 6191                     1
# 6184                     1
# 6166                     1
# 15771                    1
# 20633                    1
#
# [9794 rows x 1 columns]

# %% [markdown]
# Условие составное: человек не получил сертификат, и больше чем 30 дней отсутствует на платформе

# %%
events_data.tail()
# Out:
#          step_id   timestamp      action  user_id                date  \
# 3480698    33375  1526772685      viewed    11677 2018-05-19 23:31:25
# 3480699    32815  1526772750      viewed     5198 2018-05-19 23:32:30
# 3480700    32815  1526772750  discovered     5198 2018-05-19 23:32:30
# 3480701    32815  1526772750      passed     5198 2018-05-19 23:32:30
# 3480702    33892  1526772811      viewed    18526 2018-05-19 23:33:31
#
#                 day
# 3480698  2018-05-19
# 3480699  2018-05-19
# 3480700  2018-05-19
# 3480701  2018-05-19
# 3480702  2018-05-19

# %%
users_data = events_data.groupby('user_id', as_index=False) \
    .agg({'timestamp': 'max'}).rename(columns={'timestamp': 'last_timestamp'})

# %%
now = 1526772811
drop_out_threshold = 30 * 24 * 60 * 60

# %%
users_data['is_gone_user'] = (now - users_data.last_timestamp) > drop_out_threshold

# %%
users_data
# Out:
#        user_id  last_timestamp  is_gone_user
# 0            1      1472827464          True
# 1            2      1519226966          True
# 2            3      1444581588          True
# 3            5      1499859939          True
# 4            7      1521634660          True
# ...        ...             ...           ...
# 19229    26790      1517495987          True
# 19230    26793      1510225034          True
# 19231    26794      1512035039          True
# 19232    26797      1509995096          True
# 19233    26798      1520978742          True
#
# [19234 rows x 3 columns]

# %%
users_data = users_data.merge(users_scores, on='user_id', how='outer')

# %%
users_data = users_data.fillna(0)

# %%
users_data
# Out:
#        user_id  last_timestamp  is_gone_user  correct  wrong
# 0            1      1472827464          True      0.0    0.0
# 1            2      1519226966          True      2.0    0.0
# 2            3      1444581588          True     29.0   23.0
# 3            5      1499859939          True      2.0    2.0
# 4            7      1521634660          True      0.0    0.0
# ...        ...             ...           ...      ...    ...
# 19229    26790      1517495987          True      1.0    0.0
# 19230    26793      1510225034          True      0.0    0.0
# 19231    26794      1512035039          True     33.0    9.0
# 19232    26797      1509995096          True      2.0    0.0
# 19233    26798      1520978742          True      2.0    1.0
#
# [19234 rows x 5 columns]

# %%
users_data = users_data.merge(users_events_data, on='user_id', how='outer')

# %%
users_data
# Out:
#        user_id  last_timestamp  is_gone_user  correct  wrong  discovered  \
# 0            1      1472827464          True      0.0    0.0           1
# 1            2      1519226966          True      2.0    0.0           9
# 2            3      1444581588          True     29.0   23.0          91
# 3            5      1499859939          True      2.0    2.0          11
# 4            7      1521634660          True      0.0    0.0           1
# ...        ...             ...           ...      ...    ...         ...
# 19229    26790      1517495987          True      1.0    0.0           8
# 19230    26793      1510225034          True      0.0    0.0           1
# 19231    26794      1512035039          True     33.0    9.0          69
# 19232    26797      1509995096          True      2.0    0.0          10
# 19233    26798      1520978742          True      2.0    1.0          12
#
#        passed  started_attempt  viewed
# 0           0                0       1
# ...

# %% [markdown]
# Не хватает фичи - сколько дней наш уникальный пользователь был в степике

# %%
users_days = events_data.groupby('user_id', as_index=False).day.nunique()

# %%
users_days
# Out:
#        user_id  day
# 0            1    1
# 1            2    2
# 2            3    7
# 3            5    2
# 4            7    1
# ...        ...  ...
# 19229    26790    4
# 19230    26793    1
# 19231    26794    9
# 19232    26797    2
# 19233    26798    1
#
# [19234 rows x 2 columns]

# %%
users_data = users_data.merge(users_days, how='outer')

# %%
users_data
# Out:
#        user_id  last_timestamp  is_gone_user  correct  wrong  discovered  \
# 0            1      1472827464          True      0.0    0.0           1
# 1            2      1519226966          True      2.0    0.0           9
# 2            3      1444581588          True     29.0   23.0          91
# 3            5      1499859939          True      2.0    2.0          11
# 4            7      1521634660          True      0.0    0.0           1
# ...        ...             ...           ...      ...    ...         ...
# 19229    26790      1517495987          True      1.0    0.0           8
# 19230    26793      1510225034          True      0.0    0.0           1
# 19231    26794      1512035039          True     33.0    9.0          69
# 19232    26797      1509995096          True      2.0    0.0          10
# 19233    26798      1520978742          True      2.0    1.0          12
#
#        passed  started_attempt  viewed  day
# 0           0                0       1    1
# ...

# %%
users_data.user_id.nunique()
# Out:
# 19234

# %%
events_data.user_id.nunique()
# Out:
# 19234

# %%
users_data['passed_corse'] = users_data.passed > 170

# %%
users_data_1 = users_data.groupby('passed_corse', as_index=False).count()

# %%
users_data_1.head()
# Out:
#    passed_corse  user_id  last_timestamp  is_gone_user  correct  wrong  \
# 0         False    17809           17809         17809    17809  17809
# 1          True     1425            1425          1425     1425   1425
#
#    discovered  passed  started_attempt  viewed    day
# 0       17809   17809            17809   17809  17809
# 1        1425    1425             1425    1425   1425

# %%
users_data_1.user_id[1] / users_data_1.user_id[0]
# Out:
# 0.08001572238755686

# %%
users_data
# Out:
#        user_id  last_timestamp  is_gone_user  correct  wrong  discovered  \
# 0            1      1472827464          True      0.0    0.0           1
# 1            2      1519226966          True      2.0    0.0           9
# 2            3      1444581588          True     29.0   23.0          91
# 3            5      1499859939          True      2.0    2.0          11
# 4            7      1521634660          True      0.0    0.0           1
# ...        ...             ...           ...      ...    ...         ...
# 19229    26790      1517495987          True      1.0    0.0           8
# 19230    26793      1510225034          True      0.0    0.0           1
# 19231    26794      1512035039          True     33.0    9.0          69
# 19232    26797      1509995096          True      2.0    0.0          10
# 19233    26798      1520978742          True      2.0    1.0          12
#
#        passed  started_attempt  viewed  day  passed_corse
# ...

# %% [markdown]
# **Интересна ML задача возможно ли по поведению за первую неделю учебы предсказать закончит человек курс до конца или нет?**

# %% [markdown]
# ## Решающие деревья
#
# #### Decision Tree

# %% [markdown]
# посмотрим медианное количество дней тех, кто прошел курс

# %%
users_data[users_data.passed_corse == True].day.median()
# Out:
# 20.0

# %%
users_data[users_data.passed_corse == True].day.hist()
# Out:
# <AxesSubplot:>

# %%
users_data[users_data.passed_corse == True].day.mean()
# Out:
# 25.193684210526317

# %%
events_data.head()
# Out:
#    step_id   timestamp      action  user_id                date         day
# 0    32815  1434340848      viewed    17632 2015-06-15 04:00:48  2015-06-15
# 1    32815  1434340848      passed    17632 2015-06-15 04:00:48  2015-06-15
# 2    32815  1434340848  discovered    17632 2015-06-15 04:00:48  2015-06-15
# 3    32811  1434340895  discovered    17632 2015-06-15 04:01:35  2015-06-15
# 4    32811  1434340895      viewed    17632 2015-06-15 04:01:35  2015-06-15

# %%
user_min_time = events_data.groupby('user_id', as_index=False) \
    .agg({'timestamp': 'min'}) \
    .rename({'timestamp': 'min_timestamp'}, axis=1)

# %%
users_data = users_data.merge(user_min_time, how='outer')

# %%
events_data
# Out:
#          step_id   timestamp      action  user_id                date  \
# 0          32815  1434340848      viewed    17632 2015-06-15 04:00:48
# 1          32815  1434340848      passed    17632 2015-06-15 04:00:48
# 2          32815  1434340848  discovered    17632 2015-06-15 04:00:48
# 3          32811  1434340895  discovered    17632 2015-06-15 04:01:35
# 4          32811  1434340895      viewed    17632 2015-06-15 04:01:35
# ...          ...         ...         ...      ...                 ...
# 3480698    33375  1526772685      viewed    11677 2018-05-19 23:31:25
# 3480699    32815  1526772750      viewed     5198 2018-05-19 23:32:30
# 3480700    32815  1526772750  discovered     5198 2018-05-19 23:32:30
# 3480701    32815  1526772750      passed     5198 2018-05-19 23:32:30
# 3480702    33892  1526772811      viewed    18526 2018-05-19 23:33:31
#
#                 day
# 0        2015-06-15
# 1        2015-06-15
# 2        2015-06-15
# 3        2015-06-15
# ...

# %%
#events_data_train = 
#users_data.query(('min_timestamp' + 3 * 24 * 60 * 60) > '')

# %%
submissions_data.query('submission_status == "wrong"') \
    .groupby(['step_id'], as_index=False) \
    .agg({'submission_status': 'count'}) \
    .sort_values('submission_status', ascending=False)
# Out:
#     step_id  submission_status
# 4     31978              16084
# 11    32031              13373
# 19    32202              13002
# 44    33481              10300
# 12    32075              10003
# ..      ...                ...
# 45    33482                707
# 59    33681                703
# 36    33362                673
# 16    32175                342
# 29    32929                 85
#
# [76 rows x 2 columns]

# %%
events_data['user_time'] = events_data.user_id.map(str) + '_' + events_data.timestamp.map(str)

# %%
learning_time_threshold = 3 * 24 * 60 * 60

# %%
user_learning_time_threshold = user_min_time.user_id.map(str) + '_' + (user_min_time.min_timestamp + learning_time_threshold).map(str)

# %%
user_min_time['user_learning_time_threshold'] = user_learning_time_threshold

# %%
events_data =events_data.merge(user_min_time[['user_id', 'user_learning_time_threshold']], how='outer')
events_data
# Out:
#          step_id   timestamp      action  user_id                date  \
# 0          32815  1434340848      viewed    17632 2015-06-15 04:00:48
# 1          32815  1434340848      passed    17632 2015-06-15 04:00:48
# 2          32815  1434340848  discovered    17632 2015-06-15 04:00:48
# 3          32811  1434340895  discovered    17632 2015-06-15 04:01:35
# 4          32811  1434340895      viewed    17632 2015-06-15 04:01:35
# ...          ...         ...         ...      ...                 ...
# 3480698    32814  1526762783  discovered      943 2018-05-19 20:46:23
# 3480699    32814  1526762783      passed      943 2018-05-19 20:46:23
# 3480700    32815  1526772750      viewed     5198 2018-05-19 23:32:30
# 3480701    32815  1526772750  discovered     5198 2018-05-19 23:32:30
# 3480702    32815  1526772750      passed     5198 2018-05-19 23:32:30
#
#                 day         user_time user_learning_time_threshold
# ...

# %%
events_data_train = events_data[events_data.user_time <= events_data.user_learning_time_threshold]
events_data_train
# Out:
#          step_id   timestamp      action  user_id                date  \
# 0          32815  1434340848      viewed    17632 2015-06-15 04:00:48
# 1          32815  1434340848      passed    17632 2015-06-15 04:00:48
# 2          32815  1434340848  discovered    17632 2015-06-15 04:00:48
# 3          32811  1434340895  discovered    17632 2015-06-15 04:01:35
# 4          32811  1434340895      viewed    17632 2015-06-15 04:01:35
# ...          ...         ...         ...      ...                 ...
# 3480698    32814  1526762783  discovered      943 2018-05-19 20:46:23
# 3480699    32814  1526762783      passed      943 2018-05-19 20:46:23
# 3480700    32815  1526772750      viewed     5198 2018-05-19 23:32:30
# 3480701    32815  1526772750  discovered     5198 2018-05-19 23:32:30
# 3480702    32815  1526772750      passed     5198 2018-05-19 23:32:30
#
#                 day         user_time user_learning_time_threshold
# ...

# %%
events_data_train.groupby('user_id').day.nunique().max()
# Out:
# 4

# %%
submissions_data['users_time'] = submissions_data.user_id.map(str) + '_' + submissions_data.timestamp.map(str)
submissions_data = submissions_data.merge(user_min_time[['user_id', 'user_learning_time_threshold']], how='outer')
submissions_data_train = submissions_data[submissions_data.users_time <= submissions_data.user_learning_time_threshold]
submissions_data_train.groupby('user_id').day.nunique().max()
# Out:
# 4

# %%
X = submissions_data_train.groupby('user_id').day.nunique().to_frame().reset_index() \
    .rename({'day': 'days'}, axis=1)
steps_tried = submissions_data_train.groupby('user_id').step_id.nunique().to_frame().reset_index() \
    .rename({'step_id': 'steps_tried'}, axis=1)
X = X.merge(steps_tried, on='user_id', how='outer')
X = X.merge(users_scores, on='user_id', how='outer')
X
# Out:
#       user_id  days  steps_tried  correct  wrong
# 0           2   1.0          2.0        2      0
# 1           3   1.0          4.0       29     23
# 2           8   1.0         11.0        9     21
# 3          14   1.0          1.0        0      1
# 4          16   3.0         23.0       77    106
# ...       ...   ...          ...      ...    ...
# 9935    26737   NaN          NaN       17     45
# 9936    26742   NaN          NaN       32     22
# 9937    26753   NaN          NaN        2      0
# 9938    26772   NaN          NaN        9      5
# 9939    26781   NaN          NaN       92     75
#
# [9940 rows x 5 columns]

# %%
X['correct_ratio'] = X.correct / (X.correct + X.wrong)

# %%
X = X.fillna(0)
X
# Out:
#       user_id  days  steps_tried  correct  wrong  correct_ratio
# 0           2   1.0          2.0        2      0       1.000000
# 1           3   1.0          4.0       29     23       0.557692
# 2           8   1.0         11.0        9     21       0.300000
# 3          14   1.0          1.0        0      1       0.000000
# 4          16   3.0         23.0       77    106       0.420765
# ...       ...   ...          ...      ...    ...            ...
# 9935    26737   0.0          0.0       17     45       0.274194
# 9936    26742   0.0          0.0       32     22       0.592593
# 9937    26753   0.0          0.0        2      0       1.000000
# 9938    26772   0.0          0.0        9      5       0.642857
# 9939    26781   0.0          0.0       92     75       0.550898
#
# [9940 rows x 6 columns]

# %%
X = X.merge(users_data[['user_id', 'passed_corse', 'is_gone_user']], on='user_id', how='outer')

# %%
X = X.merge(users_events_data[['user_id', 'viewed']], on='user_id', how='outer')
X = X.fillna(0)
X
# Out:
#        user_id  days  steps_tried  correct  wrong  correct_ratio  \
# 0            2   1.0          2.0      2.0    0.0       1.000000
# 1            3   1.0          4.0     29.0   23.0       0.557692
# 2            8   1.0         11.0      9.0   21.0       0.300000
# 3           14   1.0          1.0      0.0    1.0       0.000000
# 4           16   3.0         23.0     77.0  106.0       0.420765
# ...        ...   ...          ...      ...    ...            ...
# 19229    26773   0.0          0.0      0.0    0.0       0.000000
# 19230    26774   0.0          0.0      0.0    0.0       0.000000
# 19231    26788   0.0          0.0      0.0    0.0       0.000000
# 19232    26789   0.0          0.0      0.0    0.0       0.000000
# 19233    26793   0.0          0.0      0.0    0.0       0.000000
#
#        passed_corse  is_gone_user  viewed
# 0             False          True      10
# 1             False          True     192
# 2             False          True     156
# ...

# %%
X = X[-((X.is_gone_user == False) & (X.passed_corse == False))]
X
# Out:
#        user_id  days  steps_tried  correct  wrong  correct_ratio  \
# 0            2   1.0          2.0      2.0    0.0       1.000000
# 1            3   1.0          4.0     29.0   23.0       0.557692
# 2            8   1.0         11.0      9.0   21.0       0.300000
# 3           14   1.0          1.0      0.0    1.0       0.000000
# 4           16   3.0         23.0     77.0  106.0       0.420765
# ...        ...   ...          ...      ...    ...            ...
# 19229    26773   0.0          0.0      0.0    0.0       0.000000
# 19230    26774   0.0          0.0      0.0    0.0       0.000000
# 19231    26788   0.0          0.0      0.0    0.0       0.000000
# 19232    26789   0.0          0.0      0.0    0.0       0.000000
# 19233    26793   0.0          0.0      0.0    0.0       0.000000
#
#        passed_corse  is_gone_user  viewed
# 0             False          True      10
# 1             False          True     192
# 2             False          True     156
# ...

# %%
y = X.passed_corse.map(int)

# %%
X = X.drop(['passed_corse', 'is_gone_user'], axis=1)

# %%
X = X.set_index(X.user_id)
X = X.drop('user_id', axis=1)
X
# Out:
#          days  steps_tried  correct  wrong  correct_ratio  viewed
# user_id
# 2         1.0          2.0      2.0    0.0       1.000000      10
# 3         1.0          4.0     29.0   23.0       0.557692     192
# 8         1.0         11.0      9.0   21.0       0.300000     156
# 14        1.0          1.0      0.0    1.0       0.000000       9
# 16        3.0         23.0     77.0  106.0       0.420765     651
# ...       ...          ...      ...    ...            ...     ...
# 26773     0.0          0.0      0.0    0.0       0.000000       1
# 26774     0.0          0.0      0.0    0.0       0.000000       1
# 26788     0.0          0.0      0.0    0.0       0.000000       1
# 26789     0.0          0.0      0.0    0.0       0.000000       2
# 26793     0.0          0.0      0.0    0.0       0.000000       1
#
# [17985 rows x 6 columns]

# %%
from sklearn import tree
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as ыты
# %matplotlib inline

# %%
from IPython.display import SVG
from graphviz import Source
from IPython.display import display
from IPython.display import HTML

style = "<style>svg{width:100% !important;height:100% !important;}</style>"
HTML(style)
# Out:
# <style>svg{width:100% !important;height:100% !important;}</style>

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.metrics import f1_score, accuracy_score

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
clf = tree.DecisionTreeClassifier()

# %%
parametrs = {'max_depth': range(1,10),
             'min_samples_split': range(1, 10),
             'min_samples_leaf': range(1,10)}

# %%
grid_search_cv_clf = GridSearchCV(clf, parametrs, cv=2)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
grid_search_cv_clf.fit(X_train, y_train)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\admin\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 898, in fit
#     super().fit(
#   File "C:\Users\admin\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 237, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ...

# %%
grid_search_cv_clf.best_params_
# Out:
# {'max_depth': 4, 'min_samples_leaf': 8, 'min_samples_split': 2}

# %%
best_clf = grid_search_cv_clf.best_estimator_

# %%
fig = plt.figure(figsize=(25,10))
_ = tree.plot_tree(best_clf,
                   filled=True)

# %%
y_pred = best_clf.predict(X_test)

# %%
f1_score(y_test, y_pred)
# Out:
# 0.9584736251402918

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.993766846361186
